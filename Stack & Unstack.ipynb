# %%
import pandas as pd 
import numpy as np

# %%
fuel = pd.read_csv("./data/fuel.csv",usecols=['Year','Make','Model','Range (FT1)','City Range (FT1)'])

# %%
fuel.head()
# Out:
#    Year        Make               Model  Range (FT1)  City Range (FT1)
# 0  1984  Alfa Romeo           GT V6 2.5          0.0               0.0
# 1  1984  Alfa Romeo           GT V6 2.5          0.0               0.0
# 2  1984  Alfa Romeo  Spider Veloce 2000          0.0               0.0
# 3  1984  Alfa Romeo  Spider Veloce 2000          0.0               0.0
# 4  1984  AM General   DJ Po Vehicle 2WD          0.0               0.0

# %%
fuel.drop_duplicates(['Year','Make','Model'],inplace=True)

# %%
fuel.dropna(inplace=True)

# %%
fuel.set_index(['Year','Make','Model'],inplace=True)

# %%
fuel.head()
# Out:
#                                                      Range (FT1)  \
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                   0.0
#                                  Spider Veloce 2000          0.0
#      AM General                  DJ Po Vehicle 2WD           0.0
#                                  FJ8c Post Office            0.0
#      American Motors Corporation Eagle 4WD                   0.0
#
#                                                      City Range (FT1)
# Year Make                        Model
# 1984 Alfa Romeo                  GT V6 2.5                        0.0
#                                  Spider Veloce 2000               0.0
#      AM General                  DJ Po Vehicle 2WD                0.0
#                                  FJ8c Post Office                 0.0
#      American Motors Corporation Eagle 4WD                        0.0

# %%
fuel.stack(level = -1).to_frame()
# Out:
#                                                        0
# Year Make       Model
# 1984 Alfa Romeo GT V6 2.5          Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#                 Spider Veloce 2000 Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#      AM General DJ Po Vehicle 2WD  Range (FT1)       0.0
# ...                                                  ...
# 2012 Mitsubishi Lancer             City Range (FT1)  0.0
#                 Lancer AWD         Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#                 Lancer Evolution   Range (FT1)       0.0
#                                    City Range (FT1)  0.0
#
# [26290 rows x 1 columns]

# %%
fuel.unstack()
# Out:
#                                  Range (FT1)                             \
# Model                                 09-Mar 09-May 1-Ton Truck 2WD 100
# Year Make
# 1984 AM General                          NaN    NaN             NaN NaN
#      Alfa Romeo                          NaN    NaN             NaN NaN
#      American Motors Corporation         NaN    NaN             NaN NaN
#      Aston Martin                        NaN    NaN             NaN NaN
#      Audi                                NaN    NaN             NaN NaN
# ...                                      ...    ...             ...  ..
# 2012 Maybach                             NaN    NaN             NaN NaN
#      Mazda                               NaN    NaN             NaN NaN
#      McLaren Automotive                  NaN    NaN             NaN NaN
#      Mercedes-Benz                       NaN    NaN             NaN NaN
#      Mitsubishi                          NaN    NaN             NaN NaN
#
# ...

# %%
fuel.unstack(level=0)
# Out:
#                                                  Range (FT1)                 \
# Year                                                    1984 1985 1986 1987
# Make             Model
# AM General       DJ Po Vehicle 2WD                       0.0  NaN  NaN  NaN
#                  FJ8c Post Office                        0.0  NaN  NaN  NaN
#                  Post Office DJ5 2WD                     NaN  0.0  NaN  NaN
#                  Post Office DJ8 2WD                     NaN  0.0  NaN  NaN
# ASC Incorporated GNX                                     NaN  NaN  NaN  0.0
# ...                                                      ...  ...  ...  ...
# smart            fortwo cabriolet                        NaN  NaN  NaN  NaN
#                  fortwo convertible                      NaN  NaN  NaN  NaN
#                  fortwo coupe                            NaN  NaN  NaN  NaN
#                  fortwo electric drive cabriolet         NaN  NaN  NaN  NaN
# ...

# %%
fuel.unstack(level=["Year"]).stack(level=0).head()
# Out:
# Year                                             1984  1985  1986  1987  1988  \
# Make       Model
# AM General DJ Po Vehicle 2WD   City Range (FT1)   0.0   NaN   NaN   NaN   NaN
#                                Range (FT1)        0.0   NaN   NaN   NaN   NaN
#            FJ8c Post Office    City Range (FT1)   0.0   NaN   NaN   NaN   NaN
#                                Range (FT1)        0.0   NaN   NaN   NaN   NaN
#            Post Office DJ5 2WD City Range (FT1)   NaN   0.0   NaN   NaN   NaN
#
# Year                                             1989  1990  1991  1992  1993  \
# Make       Model
# AM General DJ Po Vehicle 2WD   City Range (FT1)   NaN   NaN   NaN   NaN   NaN
#                                Range (FT1)        NaN   NaN   NaN   NaN   NaN
#            FJ8c Post Office    City Range (FT1)   NaN   NaN   NaN   NaN   NaN
#                                Range (FT1)        NaN   NaN   NaN   NaN   NaN
# ...

# %%
fuel.stack().unstack(level=["Make"])
# Out:
# Make                                       AM General  ASC Incorporated  \
# Year Model
# 1984 1000                Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#      18i                 Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#      190 D 2.2/190 E 2.3 Range (FT1)              NaN               NaN
# ...                                               ...               ...
# 2012 ZDX 4WD             City Range (FT1)         NaN               NaN
#      e6                  Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#      i-MiEV              Range (FT1)              NaN               NaN
#                          City Range (FT1)         NaN               NaN
#
# Make                                       Acura  Alfa Romeo  \
# Year Model
# ...

# %%
fuel.stack().unstack(level=["Year","Make"]).head()
# Out:
# Year                                   1984             \
# Make                             Alfa Romeo AM General
# Model
# 09-Mar          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 09-May          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 1-Ton Truck 2WD Range (FT1)             NaN        NaN
#
# Year                                                                       \
# Make                             American Motors Corporation Aston Martin
# Model
# 09-Mar          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 09-May          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 1-Ton Truck 2WD Range (FT1)                              NaN          NaN
#
# ...

# %%
fuel.stack().unstack(level=["Year","Make"]).sort_index(axis=1).head()
# Out:
# Year                                   1984             \
# Make                             AM General Alfa Romeo
# Model
# 09-Mar          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 09-May          Range (FT1)             NaN        NaN
#                 City Range (FT1)        NaN        NaN
# 1-Ton Truck 2WD Range (FT1)             NaN        NaN
#
# Year                                                                       \
# Make                             American Motors Corporation Aston Martin
# Model
# 09-Mar          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 09-May          Range (FT1)                              NaN          NaN
#                 City Range (FT1)                         NaN          NaN
# 1-Ton Truck 2WD Range (FT1)                              NaN          NaN
#
# ...
